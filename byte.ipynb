# %%
import sys
x=6.3789907632
print(sys.getsizeof(x))
# Out:
# 24

# %%
import sys
int=34355555555555555555
print(sys.getsizeof(int))
# Out:
# 36

# %%
import sys
float=6.3789907632
print(sys.getsizeof(float))
# Out:
# 24

# %%
import sys
str="Hello World"
print(sys.getsizeof(str))
# Out:
# 52

# %%
import sys
boolean=True
print(sys.getsizeof(boolean))
# Out:
# 28

# %%
import sys
complex=3+4j
print(sys.getsizeof(complex))
# Out:
# 32
