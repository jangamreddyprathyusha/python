# %%
#while using list
l=[10,20,30,40,50]
i=0
n=len(l)
while i<n:
    print(l[i])
    i+=1
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
import sys
l=[]
print(sys.getsizeof(l))
# Out:
# 56

# %%
l=[10,20,30,40,50,60]
print(list(l))
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
l=[10,20,30,40,50,60]
n=len(l)
print(n)
for i in range(0,n,3):
    print(l[i])
# Out:
# 6
# 10
# 40

# %%
l=[10,20,30,40,50,60]
i=0
n=len(l)
while i<n:
    print(l[i])
    i+=1
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
def add(x,y):
    return x+y
print(add(10,20))
# Out:
# 30

# %%
l=[10,20,30,40,50,60]
print(max(l))
print(min(l))
print(sum(l))
print(len(l))
# Out:
# 60
# 10
# 210
# 6

# %%
l=[10,20,30]
print(l[0])
print(l[2])
l.append(40)
l.append(50)
print(l)
l.insert(2,"Hi")
print(l)
# Out:
# 10
# 30
# [10, 20, 30, 40, 50]
# [10, 20, 'Hi', 30, 40, 50]

# %%
l2=[11,12,13]
l.extend(l2)
print(l)
# Out:
# [11, 12, 13, 11, 12, 13, 11, 12, 13, 11, 12, 13, 11, 12, 13, 11, 12, 13, 11, 12, 13, 11, 12, 13]

# %%
l=[11,12,13]
l.extend(l)
print(l)
# Out:
# [11, 12, 13, 11, 12, 13]

# %%
l=[10,20,30]
l3=[1,2]
x=list(l3)
x.append(l3)
print(l)
# Out:
# [10, 20, 30]

# %%
l=[10,"hi",20,30,40,"hello"]
print(l)
print(l.pop())
print(l.pop(1))
print(l.pop(3))
print(l)
l.remove(10)
print(l)
# Out:
# [10, 'hi', 20, 30, 40, 'hello']
# hello
# hi
# 40
# [10, 20, 30]
# [20, 30]

# %%
t=(10,20,30)
t=t+(40,)
print(t)
# Out:
# (10, 20, 30, 40)

# %%
l=[10,"hi",20,30,40,"hello"]
print(l)
l2=l.copy()
print(l2)
# Out:
# [10, 'hi', 20, 30, 40, 'hello']
# [10, 'hi', 20, 30, 40, 'hello']

# %%
l=[10,"hi",20,30,40,"hello"]
print(l.count(10))
l.reverse()
print(l)
# Out:
# 1
# ['hello', 40, 30, 20, 'hi', 10]

# %%
l=[10,20,60,30,40]
max=0
for val in l:
    if max<val:
      max=val
print(max)
# Out:
# 60

# %%
l=[10,20,60,30,40]
min=l[0]
for val in l:
    if min>val:
      min=val
print(min)
# Out:
# 10

# %%
l=[10,20,60,30,40]
sum=0
for val in l:
    sum+=val
print(sum)
# Out:
# 160

# %%
l=[10,20,60,30,40]
prod=1
for val in l:
    prod=prod*val
print(prod)
# Out:
# 14400000

# %%
l = [10, 20, 60, 30, 40]
count = 0
for val in l:
    count = count + 1
print(count)
# Out:
# 5

# %%
l = [10, 20, 60, 30, 40]
print(len(l))
# Out:
# 5
