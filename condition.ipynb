# %% [markdown]
# even and odd

# %%
n=int(input("enter a number:"))
if n%2==0:
    print("even number")
else:
    print("odd number")
# Out:
# odd number

# %% [markdown]
# '''positive or negitive'''

# %%
n=int(input("enter a number:"))
if n>0:
    print("positive value")
else:
    print("negitive number")
# Out:
# negitive number

# %% [markdown]
#   '''ascii values'''

# %%
s=input("enter the character:")
n=ord(s)
if n>=65 and n<=90:
    print(s,"is upper case")
else:
    print(s,"is lower case")
# Out:
# T is upper case

# %% [markdown]
# reverse value

# %%
n=int(input("enter the number: "))
rev=0
while(n>0):           #123>0, 12>0, 1>0, 0>0
    temp=n%10         #123%10=3, 12%10=2, 1%10=1
    rev=rev*10+temp   #0*10+3=3, 3*10+2=32, 32*10+1=321
    n=n//10           #123//10=12, 12//10=1, 1//10=0
print("Reverse of the number is=",rev)

# %% [markdown]
# same or not

# %%
x=10
y=10
if x^y==0:
    print(x,y,"same")
else:
    print(x,y,"not same")
# Out:
# 10 10 same

# %%
n=int(input("enter a number:"))
print(n>>1)
print(n<<1)
print(n//2)
# Out:
# 17
# 68
# 17

# %% [markdown]
# leap year

# %%
year=int(input("enter the year:"))
if (year%4==0 and year%100!=0) or year%400!=0:
    print("Leap year")
else:
    print("not year")
# Out:
# Leap year

# %% [markdown]
# marks

# %%
marks=int(input("enter the marks:"))
if marks>=950:
    print("CSE")
elif marks>=800 and marks<950:
    print("CSE-DS,AI")
elif marks>=600 and marks<800:
    print("ECE")
elif marks>=400 and marks<600:
    print("Mech or Civil")
else:
    print("EEE")

# %% [markdown]
# match()

# %%
day=input("enter a day:")
match(day):
    case "sun":
        print("project")
    case "mon":
        print("class")
    case "tue":
        print("temple")
    case "wed":
        print("bank")
# Out:
# project

# %% [markdown]
# div by 6

# %%
num=68
if num%2==0 and num%3==0:
    print(num,"is div by 6")
else:
    print(num,"is not div by 6")
# Out:
# 68 is not div by 6

# %%
if(num%2==0):
    if(num%3==0):
        print(num,"given num is div by 6")
    else:
        print(num,"is not div by 3 so not div by 6")
else:
    print(num,"is not div by 2 so not div by 6")
# Out:
# 68 is not div by 3 so not div by 6

# %%
a=10
b=40
c=20
if a>b:
    if a>c:
        print("a is greater")
    else:
        print("c is greater")
else:
    if b>c:
        print("b is greater")
    else:
        print("c is greater")
# Out:
# b is greater
